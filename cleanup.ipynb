# %%
import pandas as pd

# %%
df=pd.read_csv("stats_all.csv")
df
# Out:
#        Unnamed: 0          Player     Season   Age   Tm   Lg  Pos      G  \
# 0               0  Alaa Abdelnaby    1990-91  22.0  POR  NBA   PF   43.0
# 1               1  Alaa Abdelnaby    1991-92  23.0  POR  NBA   PF   71.0
# 2               2  Alaa Abdelnaby    1992-93  24.0  TOT  NBA   PF   75.0
# 3               3  Alaa Abdelnaby    1992-93  24.0  MIL  NBA   PF   12.0
# 4               4  Alaa Abdelnaby    1992-93  24.0  BOS  NBA   PF   63.0
# ...           ...             ...        ...   ...  ...  ...  ...    ...
# 50736          10     Ivica Zubac        NaN   NaN  NaN  NaN  NaN    NaN
# 50737          11     Ivica Zubac  5 seasons   NaN  LAC  NBA  NaN  263.0
# 50738          12     Ivica Zubac  3 seasons   NaN  LAL  NBA  NaN  114.0
# 50739           0      Matt Zunic    1948-49  29.0  WSC  BAA  NaN     56
# 50740           1      Matt Zunic     Career   NaN  NaN  BAA  NaN     56
#
#           GS    MP  ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PTS
# ...

# %%
df=df.drop("Unnamed: 0", axis=1)

# %%
df.index +=1

# %%
df=df.reset_index()
df
# Out:
#        index          Player     Season   Age   Tm   Lg  Pos      G     GS  \
# 0          1  Alaa Abdelnaby    1990-91  22.0  POR  NBA   PF   43.0    0.0
# 1          2  Alaa Abdelnaby    1991-92  23.0  POR  NBA   PF   71.0    1.0
# 2          3  Alaa Abdelnaby    1992-93  24.0  TOT  NBA   PF   75.0   52.0
# 3          4  Alaa Abdelnaby    1992-93  24.0  MIL  NBA   PF   12.0    0.0
# 4          5  Alaa Abdelnaby    1992-93  24.0  BOS  NBA   PF   63.0   52.0
# ...      ...             ...        ...   ...  ...  ...  ...    ...    ...
# 50736  50737     Ivica Zubac        NaN   NaN  NaN  NaN  NaN    NaN    NaN
# 50737  50738     Ivica Zubac  5 seasons   NaN  LAC  NBA  NaN  263.0  221.0
# 50738  50739     Ivica Zubac  3 seasons   NaN  LAL  NBA  NaN  114.0   23.0
# 50739  50740      Matt Zunic    1948-49  29.0  WSC  BAA  NaN     56    NaN
# 50740  50741      Matt Zunic     Career   NaN  NaN  BAA  NaN     56    NaN
#
#          MP  ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PTS
# ...

# %%
df=df.drop("index", axis=1)
df
# Out:
#                Player     Season   Age   Tm   Lg  Pos      G     GS    MP  \
# 0      Alaa Abdelnaby    1990-91  22.0  POR  NBA   PF   43.0    0.0   6.7
# 1      Alaa Abdelnaby    1991-92  23.0  POR  NBA   PF   71.0    1.0  13.2
# 2      Alaa Abdelnaby    1992-93  24.0  TOT  NBA   PF   75.0   52.0  17.5
# 3      Alaa Abdelnaby    1992-93  24.0  MIL  NBA   PF   12.0    0.0  13.3
# 4      Alaa Abdelnaby    1992-93  24.0  BOS  NBA   PF   63.0   52.0  18.3
# ...               ...        ...   ...  ...  ...  ...    ...    ...   ...
# 50736     Ivica Zubac        NaN   NaN  NaN  NaN  NaN    NaN    NaN   NaN
# 50737     Ivica Zubac  5 seasons   NaN  LAC  NBA  NaN  263.0  221.0  22.2
# 50738     Ivica Zubac  3 seasons   NaN  LAL  NBA  NaN  114.0   23.0  13.5
# 50739      Matt Zunic    1948-49  29.0  WSC  BAA  NaN     56    NaN   NaN
# 50740      Matt Zunic     Career   NaN  NaN  BAA  NaN     56    NaN   NaN
#
#         FG  ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PTS
# ...

# %%
df=df.rename(columns={"index": "id"})
df
# Out:
#           id          Player     Season   Age   Tm   Lg  Pos      G     GS  \
# 0          1  Alaa Abdelnaby    1990-91  22.0  POR  NBA   PF   43.0    0.0
# 1          2  Alaa Abdelnaby    1991-92  23.0  POR  NBA   PF   71.0    1.0
# 2          3  Alaa Abdelnaby    1992-93  24.0  TOT  NBA   PF   75.0   52.0
# 3          4  Alaa Abdelnaby    1992-93  24.0  MIL  NBA   PF   12.0    0.0
# 4          5  Alaa Abdelnaby    1992-93  24.0  BOS  NBA   PF   63.0   52.0
# ...      ...             ...        ...   ...  ...  ...  ...    ...    ...
# 50736  50737     Ivica Zubac        NaN   NaN  NaN  NaN  NaN    NaN    NaN
# 50737  50738     Ivica Zubac  5 seasons   NaN  LAC  NBA  NaN  263.0  221.0
# 50738  50739     Ivica Zubac  3 seasons   NaN  LAL  NBA  NaN  114.0   23.0
# 50739  50740      Matt Zunic    1948-49  29.0  WSC  BAA  NaN     56    NaN
# 50740  50741      Matt Zunic     Career   NaN  NaN  BAA  NaN     56    NaN
#
#          MP  ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PTS
# ...

# %%
df.to_csv("season_stats_all.csv")

# %%
df1=df.loc[df["Age"].isnull()==True]
df1["Season"].unique()
len(df1)
# Out:
# 19407

# %%
df2=df.loc[df["Age"].isnull()==False]
df2["Season"].unique()
df2
# Out:
#           id          Player   Season   Age   Tm   Lg  Pos     G    GS    MP  \
# 0          1  Alaa Abdelnaby  1990-91  22.0  POR  NBA   PF  43.0   0.0   6.7
# 1          2  Alaa Abdelnaby  1991-92  23.0  POR  NBA   PF  71.0   1.0  13.2
# 2          3  Alaa Abdelnaby  1992-93  24.0  TOT  NBA   PF  75.0  52.0  17.5
# 3          4  Alaa Abdelnaby  1992-93  24.0  MIL  NBA   PF  12.0   0.0  13.3
# 4          5  Alaa Abdelnaby  1992-93  24.0  BOS  NBA   PF  63.0  52.0  18.3
# ...      ...             ...      ...   ...  ...  ...  ...   ...   ...   ...
# 50731  50732     Ivica Zubac  2019-20  22.0  LAC  NBA    C  72.0  70.0  18.4
# 50732  50733     Ivica Zubac  2020-21  23.0  LAC  NBA    C  72.0  33.0  22.3
# 50733  50734     Ivica Zubac  2021-22  24.0  LAC  NBA    C  76.0  76.0  24.4
# 50734  50735     Ivica Zubac  2022-23  25.0  LAC  NBA    C  17.0  17.0  30.6
# 50739  50740      Matt Zunic  1948-49  29.0  WSC  BAA  NaN    56   NaN   NaN
#
# ...

# %%
len(df)
# Out:
# 50741

# %%
df=pd.read_csv("season_stats_all.csv")
df
# Out:
#        Unnamed: 0     id          Player     Season   Age   Tm   Lg  Pos  \
# 0               0      1  Alaa Abdelnaby    1990-91  22.0  POR  NBA   PF
# 1               1      2  Alaa Abdelnaby    1991-92  23.0  POR  NBA   PF
# 2               2      3  Alaa Abdelnaby    1992-93  24.0  TOT  NBA   PF
# 3               3      4  Alaa Abdelnaby    1992-93  24.0  MIL  NBA   PF
# 4               4      5  Alaa Abdelnaby    1992-93  24.0  BOS  NBA   PF
# ...           ...    ...             ...        ...   ...  ...  ...  ...
# 50736       50736  50737     Ivica Zubac        NaN   NaN  NaN  NaN  NaN
# 50737       50737  50738     Ivica Zubac  5 seasons   NaN  LAC  NBA  NaN
# 50738       50738  50739     Ivica Zubac  3 seasons   NaN  LAL  NBA  NaN
# 50739       50739  50740      Matt Zunic    1948-49  29.0  WSC  BAA  NaN
# 50740       50740  50741      Matt Zunic     Career   NaN  NaN  BAA  NaN
#
#            G     GS  ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PTS
# ...

# %%
df.loc[df.index==0, "PTS"]
# Out:
# 0    3.1
# Name: PTS, dtype: object

# %%
df2=df2.reset_index()

# %%
df2=df2.drop("index", axis=1)
df2
# Out:
#           id          Player   Season   Age   Tm   Lg  Pos     G    GS    MP  \
# 0          1  Alaa Abdelnaby  1990-91  22.0  POR  NBA   PF  43.0   0.0   6.7
# 1          2  Alaa Abdelnaby  1991-92  23.0  POR  NBA   PF  71.0   1.0  13.2
# 2          3  Alaa Abdelnaby  1992-93  24.0  TOT  NBA   PF  75.0  52.0  17.5
# 3          4  Alaa Abdelnaby  1992-93  24.0  MIL  NBA   PF  12.0   0.0  13.3
# 4          5  Alaa Abdelnaby  1992-93  24.0  BOS  NBA   PF  63.0  52.0  18.3
# ...      ...             ...      ...   ...  ...  ...  ...   ...   ...   ...
# 29435  50732     Ivica Zubac  2019-20  22.0  LAC  NBA    C  72.0  70.0  18.4
# 29436  50733     Ivica Zubac  2020-21  23.0  LAC  NBA    C  72.0  33.0  22.3
# 29437  50734     Ivica Zubac  2021-22  24.0  LAC  NBA    C  76.0  76.0  24.4
# 29438  50735     Ivica Zubac  2022-23  25.0  LAC  NBA    C  17.0  17.0  30.6
# 29439  50740      Matt Zunic  1948-49  29.0  WSC  BAA  NaN    56   NaN   NaN
#
# ...

# %%
counter=0
for index, row in df2.iterrows():
    if len(row["Tm"]) > 3:
        df2=df2.drop(index,axis=0)
        print("time to delete")
        counter +=1
counter
# Out:
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# time to delete
# ...

# %%
df2.to_csv("stats_clean.csv")

# %%
df2=pd.read_csv("stats_clean.csv")
df2=df2.drop("Unnamed: 0", axis=1)

# %%
df2.dtypes
# Out:
# id          int64
# Player     object
# Season     object
# Age       float64
# Tm         object
# Lg         object
# Pos        object
# G         float64
# GS        float64
# MP        float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# dtype: object

# %%
n=0
row_player=0
row_iterator=df2.iterrows()
_, last = next(row_iterator)

# %%
df2
# Out:
#           id          Player   Season   Age   Tm   Lg  Pos     G    GS    MP  \
# 0          1  Alaa Abdelnaby  1990-91  22.0  POR  NBA   PF  43.0   0.0   6.7
# 1          2  Alaa Abdelnaby  1991-92  23.0  POR  NBA   PF  71.0   1.0  13.2
# 2          3  Alaa Abdelnaby  1992-93  24.0  TOT  NBA   PF  75.0  52.0  17.5
# 3          4  Alaa Abdelnaby  1992-93  24.0  MIL  NBA   PF  12.0   0.0  13.3
# 4          5  Alaa Abdelnaby  1992-93  24.0  BOS  NBA   PF  63.0  52.0  18.3
# ...      ...             ...      ...   ...  ...  ...  ...   ...   ...   ...
# 29435  50732     Ivica Zubac  2019-20  22.0  LAC  NBA    C  72.0  70.0  18.4
# 29436  50733     Ivica Zubac  2020-21  23.0  LAC  NBA    C  72.0  33.0  22.3
# 29437  50734     Ivica Zubac  2021-22  24.0  LAC  NBA    C  76.0  76.0  24.4
# 29438  50735     Ivica Zubac  2022-23  25.0  LAC  NBA    C  17.0  17.0  30.6
# 29439  50740      Matt Zunic  1948-49  29.0  WSC  BAA  NaN  56.0   NaN   NaN
#
# ...

# %%
player=""
season=""
counter=0
list0=[]
list1=[]
list2=[]
df_1=df2
for index, row in df2.iterrows():
    if (row["Age"]==last["Age"]) & (row["id"]!=1):
        print(str(index) + " next row player " + str(last["Player"])+ " next row age " + str(last["PTS"]) + " current row player " + str(row["Player"]) + str(row["Age"]))
        df2.drop(index, inplace=True)
    
    
    last=row
        

df2
# Out:
# 3 next row player Alaa Abdelnaby next row age 7.7 current row player Alaa Abdelnaby24.0
# 4 next row player Alaa Abdelnaby next row age 5.3 current row player Alaa Abdelnaby24.0
# 7 next row player Alaa Abdelnaby next row age 4.7 current row player Alaa Abdelnaby26.0
# 8 next row player Alaa Abdelnaby next row age 5.0 current row player Alaa Abdelnaby26.0
# 10 next row player Zaid Abdul-Aziz next row age 7.3 current row player Zaid Abdul-Aziz22.0
# 11 next row player Zaid Abdul-Aziz next row age 1.9 current row player Zaid Abdul-Aziz22.0
# 21 next row player Zaid Abdul-Aziz next row age 3.9 current row player Zaid Abdul-Aziz31.0
# 22 next row player Zaid Abdul-Aziz next row age 4.0 current row player Zaid Abdul-Aziz31.0
# 52 next row player Mahmoud Abdul-Rauf next row age 4.7 current row player Mahmoud Abdul-Rauf30.0
# 53 next row player Mahmoud Abdul-Rauf next row age 5.9 current row player Mahmoud Abdul-Rauf30.0
# ...

# %%
df2
# Out:
#           id          Player   Season   Age   Tm   Lg  Pos     G    GS    MP  \
# 0          1  Alaa Abdelnaby  1990-91  22.0  POR  NBA   PF  43.0   0.0   6.7
# 1          2  Alaa Abdelnaby  1991-92  23.0  POR  NBA   PF  71.0   1.0  13.2
# 2          3  Alaa Abdelnaby  1992-93  24.0  TOT  NBA   PF  75.0  52.0  17.5
# 5          6  Alaa Abdelnaby  1993-94  25.0  BOS  NBA   PF  13.0   0.0  12.2
# 6          7  Alaa Abdelnaby  1994-95  26.0  TOT  NBA   PF  54.0   0.0   9.4
# ...      ...             ...      ...   ...  ...  ...  ...   ...   ...   ...
# 29435  50732     Ivica Zubac  2019-20  22.0  LAC  NBA    C  72.0  70.0  18.4
# 29436  50733     Ivica Zubac  2020-21  23.0  LAC  NBA    C  72.0  33.0  22.3
# 29437  50734     Ivica Zubac  2021-22  24.0  LAC  NBA    C  76.0  76.0  24.4
# 29438  50735     Ivica Zubac  2022-23  25.0  LAC  NBA    C  17.0  17.0  30.6
# 29439  50740      Matt Zunic  1948-49  29.0  WSC  BAA  NaN  56.0   NaN   NaN
#
# ...

# %%
df2=df2.reset_index()

# %%
df2=df2.drop("index", axis=1)

# %%
df2
# Out:
#           id          Player   Season   Age   Tm   Lg  Pos     G    GS    MP  \
# 0          1  Alaa Abdelnaby  1990-91  22.0  POR  NBA   PF  43.0   0.0   6.7
# 1          2  Alaa Abdelnaby  1991-92  23.0  POR  NBA   PF  71.0   1.0  13.2
# 2          3  Alaa Abdelnaby  1992-93  24.0  TOT  NBA   PF  75.0  52.0  17.5
# 3          4  Alaa Abdelnaby  1992-93  24.0  MIL  NBA   PF  12.0   0.0  13.3
# 4          7  Alaa Abdelnaby  1994-95  26.0  TOT  NBA   PF  54.0   0.0   9.4
# ...      ...             ...      ...   ...  ...  ...  ...   ...   ...   ...
# 23480  50730     Ivica Zubac  2018-19  21.0  LAL  NBA    C  33.0  12.0  15.6
# 23481  50733     Ivica Zubac  2020-21  23.0  LAC  NBA    C  72.0  33.0  22.3
# 23482  50734     Ivica Zubac  2021-22  24.0  LAC  NBA    C  76.0  76.0  24.4
# 23483  50735     Ivica Zubac  2022-23  25.0  LAC  NBA    C  17.0  17.0  30.6
# 23484  50740      Matt Zunic  1948-49  29.0  WSC  BAA  NaN  56.0   NaN   NaN
#
# ...

# %%
season=""
counter=0
list0=[]
list1=[]
list2=[]
df_1=df2
for index, row in df2.iterrows():
    if (row["Age"]==last["Age"]):
        print(str(index) + " next row player " + str(last["Player"])+ " next row age " + str(last["Age"]) + " current row player " + str(row["Player"]) + str(row["Age"]))
        
        if row["id"] != 1:
            df2.drop(index+1, inplace=True)
            last=row
        else:
            last=row
    last=row
        

df2
# Out:
# 3 next row player Alaa Abdelnaby next row age 24.0 current row player Alaa Abdelnaby24.0
# 5 next row player Alaa Abdelnaby next row age 26.0 current row player Alaa Abdelnaby26.0
# 15 next row player Zaid Abdul-Aziz next row age 31.0 current row player Zaid Abdul-Aziz31.0
# 44 next row player Mahmoud Abdul-Rauf next row age 30.0 current row player Mahmoud Abdul-Rauf30.0
# 48 next row player Tariq Abdul-Wahad next row age 25.0 current row player Tariq Abdul-Wahad25.0
# 50 next row player Tariq Abdul-Wahad next row age 27.0 current row player Tariq Abdul-Wahad27.0
# 59 next row player Shareef Abdur-Rahim next row age 27.0 current row player Shareef Abdur-Rahim27.0
# 68 next row player Tom Abernethy next row age 26.0 current row player Tom Abernethy26.0
# 71 next row player John Abramovic next row age 28.0 current row player John Abramovic28.0
# 74 next row player Precious Achiuwa next row age 23.0 current row player Alex Acker23.0
# ...

# %%
df2.to_csv('stats_cleaned_latest.csv')

# %%
df2=df2.reset_index()
df2=df2.drop("index", axis=1)

# %%
season=""
counter=0
list0=[]
list1=[]
list2=[]
df_1=df2
for index, row in df2.iterrows():
    if (row["Age"]==last["Age"]):
        print(str(index) + " next row player " + str(last["Player"])+ " next row age " + str(last["Age"]) + " current row player " + str(row["Player"]) + str(row["Age"]))
            df2.drop(index+1, inplace=True)
            last=row
        else:
            last=row
    last=row
        

df2
# Out:
# 3 next row player Alaa Abdelnaby next row age 24.0 current row player Alaa Abdelnaby24.0
# 13 next row player Zaid Abdul-Aziz next row age 31.0 current row player Zaid Abdul-Aziz31.0
# 41 next row player Mahmoud Abdul-Rauf next row age 30.0 current row player Mahmoud Abdul-Rauf30.0
# 44 next row player Tariq Abdul-Wahad next row age 25.0 current row player Tariq Abdul-Wahad25.0
# 53 next row player Shareef Abdur-Rahim next row age 27.0 current row player Shareef Abdur-Rahim27.0
# 61 next row player Tom Abernethy next row age 26.0 current row player Tom Abernethy26.0
# 63 next row player John Abramovic next row age 28.0 current row player John Abramovic28.0
# 65 next row player Precious Achiuwa next row age 23.0 current row player Alex Acker23.0
# 72 next row player Mark Acres next row age 30.0 current row player Mark Acres30.0
# 74 next row player Quincy Acy next row age 23.0 current row player Quincy Acy23.0
# ...

# %%
dfola=df2.loc[df2["Player"]=='Victor Oladipo']
dfola
# Out:
#           id          Player   Season   Age   Tm   Lg Pos     G    GS    MP  \
# 14207  34268  Victor Oladipo  2013-14  21.0  ORL  NBA  PG  80.0  44.0  31.1
# 14208  34269  Victor Oladipo  2014-15  22.0  ORL  NBA  SG  72.0  71.0  35.7
# 14209  34270  Victor Oladipo  2015-16  23.0  ORL  NBA  SG  72.0  52.0  33.0
# 14210  34271  Victor Oladipo  2016-17  24.0  OKC  NBA  SG  67.0  67.0  33.2
# 14211  34272  Victor Oladipo  2017-18  25.0  IND  NBA  SG  75.0  75.0  34.0
# 14212  34273  Victor Oladipo  2018-19  26.0  IND  NBA  SG  36.0  36.0  31.9
# 14213  34274  Victor Oladipo  2019-20  27.0  IND  NBA  SG  19.0  16.0  27.8
# 14214  34275  Victor Oladipo  2020-21  28.0  TOT  NBA  SG  33.0  33.0  32.7
# 14215  34276  Victor Oladipo  2020-21  28.0  IND  NBA  SG   9.0   9.0  33.3
#
#        ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 14207  ...  0.780  0.5  3.6  4.1  4.1  1.6  0.5  3.2  2.6  13.8
# 14208  ...  0.819  0.7  3.5  4.2  4.1  1.7  0.3  2.8  2.6  17.9
# ...

# %%
df2=df2.loc[df2["Player"]=="Victor Oladipo"]
df2

# %%
df2

# %%
df2
# Out:
#           id          Player   Season   Age   Tm   Lg  Pos     G    GS    MP  \
# 0          1  Alaa Abdelnaby  1990-91  22.0  POR  NBA   PF  43.0   0.0   6.7
# 1          2  Alaa Abdelnaby  1991-92  23.0  POR  NBA   PF  71.0   1.0  13.2
# 2          3  Alaa Abdelnaby  1992-93  24.0  TOT  NBA   PF  75.0  52.0  17.5
# 3          4  Alaa Abdelnaby  1992-93  24.0  MIL  NBA   PF  12.0   0.0  13.3
# 4          5  Alaa Abdelnaby  1992-93  24.0  BOS  NBA   PF  63.0  52.0  18.3
# ...      ...             ...      ...   ...  ...  ...  ...   ...   ...   ...
# 29435  50732     Ivica Zubac  2019-20  22.0  LAC  NBA    C  72.0  70.0  18.4
# 29436  50733     Ivica Zubac  2020-21  23.0  LAC  NBA    C  72.0  33.0  22.3
# 29437  50734     Ivica Zubac  2021-22  24.0  LAC  NBA    C  76.0  76.0  24.4
# 29438  50735     Ivica Zubac  2022-23  25.0  LAC  NBA    C  17.0  17.0  30.6
# 29439  50740      Matt Zunic  1948-49  29.0  WSC  BAA  NaN    56   NaN   NaN
#
# ...

# %%
df_1
# Out:
#           id          Player   Season   Age   Tm   Lg  Pos     G    GS    MP  \
# 0          1  Alaa Abdelnaby  1990-91  22.0  POR  NBA   PF  43.0   0.0   6.7
# 1          2  Alaa Abdelnaby  1991-92  23.0  POR  NBA   PF  71.0   1.0  13.2
# 2          3  Alaa Abdelnaby  1992-93  24.0  TOT  NBA   PF  75.0  52.0  17.5
# 3          5  Alaa Abdelnaby  1992-93  24.0  BOS  NBA   PF  63.0  52.0  18.3
# 4          6  Alaa Abdelnaby  1993-94  25.0  BOS  NBA   PF  13.0   0.0  12.2
# ...      ...             ...      ...   ...  ...  ...  ...   ...   ...   ...
# 26762  50731     Ivica Zubac  2018-19  21.0  LAC  NBA    C  26.0  25.0  20.2
# 26764  50733     Ivica Zubac  2020-21  23.0  LAC  NBA    C  72.0  33.0  22.3
# 26765  50734     Ivica Zubac  2021-22  24.0  LAC  NBA    C  76.0  76.0  24.4
# 26766  50735     Ivica Zubac  2022-23  25.0  LAC  NBA    C  17.0  17.0  30.6
# 26767  50740      Matt Zunic  1948-49  29.0  WSC  BAA  NaN    56   NaN   NaN
#
# ...

# %%
df5=df2.loc[df2["Player"]=="Victor Oladipo", :]
df5
# Out:
#           id          Player   Season   Age   Tm   Lg Pos     G    GS    MP  \
# 19930  34268  Victor Oladipo  2013-14  21.0  ORL  NBA  PG  80.0  44.0  31.1
# 19931  34269  Victor Oladipo  2014-15  22.0  ORL  NBA  SG  72.0  71.0  35.7
# 19932  34270  Victor Oladipo  2015-16  23.0  ORL  NBA  SG  72.0  52.0  33.0
# 19933  34271  Victor Oladipo  2016-17  24.0  OKC  NBA  SG  67.0  67.0  33.2
# 19934  34272  Victor Oladipo  2017-18  25.0  IND  NBA  SG  75.0  75.0  34.0
# 19935  34273  Victor Oladipo  2018-19  26.0  IND  NBA  SG  36.0  36.0  31.9
# 19936  34274  Victor Oladipo  2019-20  27.0  IND  NBA  SG  19.0  16.0  27.8
# 19937  34275  Victor Oladipo  2020-21  28.0  TOT  NBA  SG  33.0  33.0  32.7
# 19939  34277  Victor Oladipo  2020-21  28.0  HOU  NBA  SG  20.0  20.0  33.5
# 19940  34278  Victor Oladipo  2020-21  28.0  MIA  NBA  SG   4.0   4.0  27.8
# 19941  34279  Victor Oladipo  2021-22  29.0  MIA  NBA  SG   8.0   1.0  21.6
#
# ...

# %%
df3=df3.loc[df3["Player"]=="Victor Oladipo"]
df3
# Out:
#           id          Player   Season   Age   Tm   Lg Pos     G    GS    MP  \
# 19937  34275  Victor Oladipo  2020-21  28.0  TOT  NBA  SG  33.0  33.0  32.7
# 19939  34277  Victor Oladipo  2020-21  28.0  HOU  NBA  SG  20.0  20.0  33.5
# 19940  34278  Victor Oladipo  2020-21  28.0  MIA  NBA  SG   4.0   4.0  27.8
#
#        ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 19937  ...  0.754  0.4  4.5  4.8  4.6  1.4  0.4  2.5  2.5  19.8
# 19939  ...  0.783  0.4  4.4  4.8  5.0  1.2  0.5  2.6  2.3  21.2
# 19940  ...  0.667  0.8  2.8  3.5  3.5  1.8  0.5  3.5  3.3  12.0
#
# [3 rows x 32 columns]

# %%
df2.loc[df2["Season"]==]

# %%
counter=0
for index, row in df2.iterrows():
    if (row["Player"]==df2["Player"][index+1]) & (df2["Season"][index]==df2["Season"][index+1]):
        if df["Tm"][index] != "TOT":
            df=df.drop(row)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
good_dates = df.Season.value_counts().loc[lambda s: s > 1].index.tolist()
filtered_filea = df[df.data.isin(good_dates)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [22], in <cell line: 2>()
#       1 good_dates = df.Season.value_counts().loc[lambda s: s > 1].index.tolist()
# ----> 2 filtered_filea = df[df.data.isin(good_dates)]
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
dfseas=dfseas.loc[dfseas["Player"]=="Victor Oladipo"]
dfseas
# Out:
#           id          Player   Season   Age   Tm   Lg Pos     G    GS    MP  \
# 34274  34275  Victor Oladipo  2020-21  28.0  TOT  NBA  SG  33.0  33.0  32.7
# 34275  34276  Victor Oladipo  2020-21  28.0  IND  NBA  SG   9.0   9.0  33.3
# 34276  34277  Victor Oladipo  2020-21  28.0  HOU  NBA  SG  20.0  20.0  33.5
# 34277  34278  Victor Oladipo  2020-21  28.0  MIA  NBA  SG   4.0   4.0  27.8
#
#        ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 34274  ...  0.754  0.4  4.5  4.8  4.6  1.4  0.4  2.5  2.5  19.8
# 34275  ...   0.73  0.1  5.6  5.7  4.2  1.7  0.2  2.0  2.6  20.0
# 34276  ...  0.783  0.4  4.4  4.8  5.0  1.2  0.5  2.6  2.3  21.2
# 34277  ...  0.667  0.8  2.8  3.5  3.5  1.8  0.5  3.5  3.3  12.0
#
# [4 rows x 32 columns]

# %%
dfseas
# Out:
# Empty DataFrame
# Columns: [id, Player, Season, Age, Tm, Lg, Pos, G, GS, MP, FG, FGA, FG%, 3P, 3PA, 3P%, 2P, 2PA, 2P%, eFG%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS]
# Index: []
#
# [0 rows x 32 columns]

# %%
from sqlalchemy import create_engine, inspect
# create conneciton to PostgreSQL
protocol = 'postgresql'
username = 'postgres'
password = 'bootcamp'
host = 'localhost'
port = 5432
database_name = 'nba_stats_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

# %%
# Confirm tables
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['season_stats_all']

# %%
df.to_sql(name='season_stats_all', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1788, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1787     if not evt_handled:
# -> 1788         self.dialect.do_executemany(
#    1789             cursor, statement, parameters, context
#    1790         )
#    1791 elif not parameters and context.no_parameters:
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py:951, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     950     xtras = self._psycopg2_extras()
# --> 951     context._psycopg2_fetched_rows = xtras.execute_values(
#     952         cursor,
#     953         statement,
#     954         parameters,
# ...
